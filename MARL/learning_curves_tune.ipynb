# %%
import os
import tensorflow as tf
from tensorflow.core.util import event_pb2
import glob
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

figsize=(12, 8)
export_dir = './plots_tune/'
data_dir = '/home/yuxin/ray_results/PPO/PPO_meltingpot_'
env_name = 'stag_hunt'
env_list = [env_name+'_S_5M', env_name+'_M_5M', env_name+'_L_5M', env_name+'_O_5M']
env_size = ['Small', 'Medium', 'Large', 'Obstacle']
total_timestep = 6e6

sns.set()
sns.set_context("talk")
sns.set(rc={'figure.figsize':figsize})
sns.set_style("darkgrid", {"axes.facecolor":".93"})

# %%
def get_section_results(file, env_name, *tags):
    data_dict = {'env_step': [], 'env_name': []}
    data_dict.update({tag: [] for tag in tags})
    max_step = -1
    for e in tf.compat.v1.train.summary_iterator(file):
        prev_step = -1
        for v in e.summary.value:
            if v.tag in data_dict:
                data_dict[v.tag].append(v.simple_value)
                if prev_step != e.step:
                    prev_step = e.step
                    if max_step < e.step:
                        max_step = e.step
                        data_dict['env_step'].append(e.step)
                        data_dict['env_name'].append(env_name)
    data_dict = {tag: np.array(data_dict[tag]) for tag in data_dict}
    return data_dict

# %%
def read_evaluation_data(env_list, size, smooth_alpha):
    full_data = pd.DataFrame()
    plot_data = pd.DataFrame()

    for _ in np.arange(len(env_list)):
        env = env_list[_]
        logdir = os.path.join(data_dir+env, 'events*')
        print(logdir)
        eventfile = glob.glob(logdir)[0]
        data_dict = get_section_results(eventfile, env_size[_], 'ray/tune/policy_reward_min/agent_0',
                                        'ray/tune/policy_reward_mean/agent_0','ray/tune/policy_reward_max/agent_0')
        data = pd.DataFrame(data_dict)
        for (columnName, columnData) in data.items():
            if columnName != 'env_step' and columnName != 'env_name':
                data[f'{columnName}_smooth'] = data[columnName].ewm(alpha=smooth_alpha).mean()

        # reduce size for plotting
        count_row = data.shape[0]
        reduced_row = np.linspace(0, count_row-1, size, dtype=int, endpoint=True)
        data_p = data.iloc[reduced_row]

        full_data = pd.concat([full_data, data], axis=0)
        plot_data = pd.concat([plot_data, data_p], axis=0)
    return full_data, plot_data

# %%
data, data_plot = read_evaluation_data(env_list, 500, 0.2)
# Out:
# /home/yuxin/ray_results/PPO/PPO_meltingpot_stag_hunt_S_5M/events*
# /home/yuxin/ray_results/PPO/PPO_meltingpot_stag_hunt_M_5M/events*
# /home/yuxin/ray_results/PPO/PPO_meltingpot_stag_hunt_L_5M/events*
# /home/yuxin/ray_results/PPO/PPO_meltingpot_stag_hunt_O_5M/events*

# %%
data_plot
# Out:
#       env_step  env_name  ray/tune/policy_reward_min/agent_0  \
# 0         3200     Small                           22.034920
# 6        12800     Small                           22.034920
# 12       22400     Small                           22.034920
# 18       32000     Small                           22.034920
# 25       43200     Small                           22.034920
# ...        ...       ...                                 ...
# 3096   4958400  Obstacle                           11.588477
# 3103   4969600  Obstacle                           11.588477
# 3109   4979200  Obstacle                           11.588477
# 3115   4988800  Obstacle                           11.588477
# 3122   5000000  Obstacle                           11.588477
#
#       ray/tune/policy_reward_mean/agent_0  ray/tune/policy_reward_max/agent_0  \
# 0                               24.861904                           27.688889
# 6                               38.700714                           54.788887
# 12                              35.524681                           54.788887
# 18                              39.062099                           57.708202
# 25                              40.619720                           57.708202
# ...                                   ...                                 ...
# 3096                            25.524015                           51.518421
# 3103                            25.732725                           51.518421
# 3109                            26.052105                           51.518421
# 3115                            25.842077                           51.518421
# 3122                            25.778049                           51.518421
#
#       ray/tune/policy_reward_min/agent_0_smooth  \
# 0                                     22.034920
# 6                                     22.034920
# 12                                    22.034920
# 18                                    22.034920
# 25                                    22.034920
# ...                                         ...
# 3096                                  11.582975
# 3103                                  11.587323
# 3109                                  11.588175
# 3115                                  11.588398
# 3122                                  11.588461
#
#       ray/tune/policy_reward_mean/agent_0_smooth  \
# 0                                      24.861904
# 6                                      33.583533
# 12                                     36.223017
# 18                                     37.998032
# 25                                     39.997632
# ...                                          ...
# 3096                                   25.625610
# 3103                                   25.537271
# 3109                                   25.795467
# 3115                                   25.899452
# 3122                                   25.911972
#
#       ray/tune/policy_reward_max/agent_0_smooth
# 0                                     27.688889
# 6                                     45.173206
# 12                                    52.680936
# 18                                    55.704500
# 25                                    57.292796
# ...                                         ...
# 3096                                  51.174211
# 3103                                  51.446235
# 3109                                  51.499498
# 3115                                  51.513461
# 3122                                  51.517381
#
# [2000 rows x 8 columns]

# %%
fig, ax = plt.subplots(figsize=figsize)
g = sns.lineplot(data=data_plot, x='env_step', y='ray/tune/policy_reward_min/agent_0', hue='env_name')
ax.set(xlabel='Total steps', ylabel='Policy Reward Min')
ax.set_title((env_name.replace('_',' ')+' Episode Reward Min').title(), fontsize=20, y=1.0)
# plt.xticks(np.arange(0, total_timestep, 5e5))
# xlabels = ['{:.1f}'.format(x) + 'M' for x in g.get_xticks()/1e6]
# g.set_xticklabels(xlabels)
plt.legend(title='Config Size')
plt.savefig(os.path.join(export_dir, env_name+' tune reward min.pdf'), bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=figsize)
g = sns.lineplot(data=data_plot, x='env_step', y='ray/tune/policy_reward_mean/agent_0', hue='env_name')
ax.set(xlabel='Total steps', ylabel='Policy Reward Mean')
ax.set_title((env_name.replace('_',' ')+' Episode Reward Mean').title(), fontsize=20, y=1.0)
# plt.xticks(np.arange(0, total_timestep, 5e5))
# xlabels = ['{:.1f}'.format(x) + 'M' for x in g.get_xticks()/1e6]
# g.set_xticklabels(xlabels)
plt.savefig(os.path.join(export_dir, env_name+' tune reward mean.pdf'), bbox_inches='tight')

# %%
fig, ax = plt.subplots(figsize=figsize)
g = sns.lineplot(data=data_plot, x='env_step', y='ray/tune/policy_reward_max/agent_0', hue='env_name')
ax.set(xlabel='Total steps', ylabel='Policy Reward Max')
ax.set_title((env_name.replace('_',' ')+' Episode Reward Max').title(), fontsize=20, y=1.0)
# plt.xticks(np.arange(0, total_timestep, 5e5))
# xlabels = ['{:.1f}'.format(x) + 'M' for x in g.get_xticks()/1e6]
# g.set_xticklabels(xlabels)
plt.savefig(os.path.join(export_dir, env_name+' tune reward max.pdf'), bbox_inches='tight')
